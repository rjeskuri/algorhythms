# %%
import pickle
import pandas as pd
import glob
import configparser
import os
import altair as alt
import numpy as np

# %%
config_options = configparser.ConfigParser()
conf_dir = os.environ.get('SPARK_CONF_DIR') or 'conf'  # Options to support Spark CLuster and local modes
config_options.read('{}/spark.conf'.format(conf_dir))  # Load entries defined in 'spark-start' shell script
dataBaseDirectory = dict(config_options.items("SPARK_APP_CONFIGS")).get('spark.sql.warehouse.dir')
print(dataBaseDirectory)
# Out:
# /scratch/siads699s23_class_root/siads699s23_class/shared_data/team_16_algorhythms/data/spark_table_warehouse

# %%
trackIndexDictFile = 'version_20230804_030210/dict_of_index_to_track_uri_and_names_20230804_030210.pkl'
pathtodict = "{}/saved_files/data_representations/{}".format(dataBaseDirectory,trackIndexDictFile)
with open(pathtodict, 'rb') as file:
    indexTrackDict = pickle.load(file)
    
# Read in dataframe using the dictionary which has index: numpy.record(with 3 elements)
indexTrackDictDf = pd.DataFrame.from_dict(indexTrackDict, orient='index', columns=['track'])

# Use vectorized operations to split the numpy record into separate columns
indexTrackDictDf['track_uri'] = indexTrackDictDf['track'].str[0]
indexTrackDictDf['track_name'] = indexTrackDictDf['track'].str[1]
indexTrackDictDf['artist_name'] = indexTrackDictDf['track'].str[2]

# Drop the original 'track' column
indexTrackDictDf.drop(columns=['track'], inplace=True)

# %%
# Print a sample of the index showing track URI
indexTrackDictDf.sample(15)
# Out:
#                                     track_uri  \
# 1228452  spotify:track:5C5NpFojn0PdAz0ZqiXGEt
# 937420   spotify:track:6vJT4fxvmjcXComT2nRRE7
# 1787407  spotify:track:62syCi5Lpy3ey4uLqU3gMU
# 516284   spotify:track:2AQh8PzzaRk9p9ymJReXwu
# 2114652  spotify:track:1M92atDuShDTaAOEkNXGr4
# 2122893  spotify:track:5gvEU8LlX3KhXMqKWiLasg
# 1133189  spotify:track:6CVGaRH8P1OQlFrCk0Vrqa
# 1133177  spotify:track:381N0PSxC20dP6qAse9O5X
# 29218    spotify:track:5OpnvBUT2qqtd2eTy9TMTz
# 598628   spotify:track:1aq0Fs2Qkivhu8dn7TskfE
# 28180    spotify:track:0ARMXOqN8YG3OAiEi2uBYp
# 1437169  spotify:track:4JESql5BQYyp3W53ebRCOU
# 306757   spotify:track:6sfO4X9Mw1NSbuPb0kBM9k
# 2231253  spotify:track:4qXBIOzkx07tR3hKaEejWh
# 613094   spotify:track:1Gde0bfBP6VJVBUkaFZMxz
#
#                                                 track_name  \
# 1228452                                        Cotton Tail
# 937420                                Grab A Body - B-Side
# 1787407                                          Rock Love
# 516284                                   Did You Wanna Die
# 2114652                                      Como Te Perdi
# 2122893                                           Chinedum
# 1133189                         Strange Noises in the Dark
# 1133177                                   Para Que Regrese
# 29218                                   Columbian Exchange
# 598628                                       Viva Louremil
# 28180                                               Violet
# 1437169                                           Our Town
# 306757   God Bless America - And All The Beautiful Wome...
# 2231253                                           Corvette
# 613094                                        Watching You
#
#                               artist_name
# 1228452                       Ben Webster
# 937420                  My Morning Jacket
# 1787407                       Lando Chill
# 516284                      Youth Brigade
# 2114652  Grupo Maravilla De Robin Revilla
# 2122893                            Flavor
# 1133189             Austin Lounge Lizards
# 1133177                         Mi Sonora
# 29218                              Fxxxxy
# 598628                    Mestre Acordeon
# 28180                      Paradise Fears
# 1437169                       Willy Mason
# 306757                       Lana Del Rey
# 2231253                             Sasha
# 613094                              Slave

# %%
# Specify the path to the CSV file for Spotify data that contains ALL tracks 
spotifyCsvFile = "{}/{}"  \
            .format(dataBaseDirectory, 'spotifyapi_tracks_all.csv' )
print("Spotify feature data CSV is : {}".format(spotifyCsvFile))
featureDf = pd.read_csv(spotifyCsvFile).dropna()
# Out:
# Spotify feature data CSV is : /scratch/siads699s23_class_root/siads699s23_class/shared_data/team_16_algorhythms/data/spark_table_warehouse/spotifyapi_tracks_all.csv

# %%
featureDf.sample(15).set_index('track_uri')
# Out:
#                                       danceability  energy  key  loudness  \
# track_uri
# spotify:track:0WLEwoxMXs9IFUgb2Jgevk         0.432  0.0198    7   -30.029
# spotify:track:1BWb2tnk5LYKvPb4sifpjD         0.701  0.7400    5    -5.689
# spotify:track:79UErtK3HJstQf7XykSmI3         0.764  0.5050    1   -12.281
# spotify:track:5jDbwyetPAbzWU5YoTnHQ4         0.361  0.1360    0   -19.613
# spotify:track:3WbYOiTaVcFfq9YETajLHz         0.620  0.5730    6    -8.323
# spotify:track:3Kbh07ClPQUAFnf6e1mIum         0.894  0.4420    0    -8.527
# spotify:track:2pCLewVg8ZoOKzLgurnrBQ         0.386  0.9570    2    -3.946
# spotify:track:6culLN522QzyF4JTwnIBT8         0.748  0.5540    1   -10.454
# spotify:track:6fWJFI8MXTBhMWr2Q0mayH         0.460  0.5880    1   -10.269
# spotify:track:7pfm2SPFWlx3YhKPpFJjaM         0.672  0.7120   11    -7.561
# spotify:track:4Ax24dp7sD4da6WcqjICqw         0.203  0.0898    7   -22.294
# spotify:track:3Q9OB9hsyD5L0nc9nqEs6C         0.688  0.8370    8    -6.006
# spotify:track:2x10hwxxBN13BRSX7uhmmA         0.542  0.9330    0    -9.668
# spotify:track:4rcjT9jHzJS5esCbJwUlqe         0.784  0.5120    6    -9.135
# spotify:track:1Aah00kVOuwwpnMDkoJMST         0.480  0.9200    3    -4.666
#
#                                       mode  speechiness  acousticness  \
# track_uri
# spotify:track:0WLEwoxMXs9IFUgb2Jgevk     1       0.0400      0.958000
# spotify:track:1BWb2tnk5LYKvPb4sifpjD     0       0.1250      0.110000
# spotify:track:79UErtK3HJstQf7XykSmI3     1       0.0829      0.022300
# spotify:track:5jDbwyetPAbzWU5YoTnHQ4     1       0.0350      0.979000
# spotify:track:3WbYOiTaVcFfq9YETajLHz     1       0.2950      0.484000
# spotify:track:3Kbh07ClPQUAFnf6e1mIum     1       0.3730      0.091100
# spotify:track:2pCLewVg8ZoOKzLgurnrBQ     1       0.1250      0.000166
# spotify:track:6culLN522QzyF4JTwnIBT8     0       0.9090      0.936000
# spotify:track:6fWJFI8MXTBhMWr2Q0mayH     0       0.0414      0.279000
# spotify:track:7pfm2SPFWlx3YhKPpFJjaM     1       0.0484      0.056800
# spotify:track:4Ax24dp7sD4da6WcqjICqw     1       0.0444      0.990000
# spotify:track:3Q9OB9hsyD5L0nc9nqEs6C     0       0.0531      0.006570
# spotify:track:2x10hwxxBN13BRSX7uhmmA     1       0.0527      0.000209
# spotify:track:4rcjT9jHzJS5esCbJwUlqe     1       0.0577      0.402000
# spotify:track:1Aah00kVOuwwpnMDkoJMST     0       0.0400      0.000174
#
#                                       instrumentalness  liveness  valence  \
# track_uri
# spotify:track:0WLEwoxMXs9IFUgb2Jgevk          0.000000    0.2320   0.1960
# spotify:track:1BWb2tnk5LYKvPb4sifpjD          0.000000    0.0967   0.7000
# spotify:track:79UErtK3HJstQf7XykSmI3          0.000266    0.3200   0.0951
# spotify:track:5jDbwyetPAbzWU5YoTnHQ4          0.913000    0.2280   0.2770
# spotify:track:3WbYOiTaVcFfq9YETajLHz          0.000000    0.3920   0.5580
# spotify:track:3Kbh07ClPQUAFnf6e1mIum          0.000000    0.0676   0.6570
# spotify:track:2pCLewVg8ZoOKzLgurnrBQ          0.002250    0.0967   0.1940
# spotify:track:6culLN522QzyF4JTwnIBT8          0.000000    0.5970   0.8270
# spotify:track:6fWJFI8MXTBhMWr2Q0mayH          0.291000    0.0791   0.4140
# spotify:track:7pfm2SPFWlx3YhKPpFJjaM          0.000653    0.0564   0.7940
# spotify:track:4Ax24dp7sD4da6WcqjICqw          0.863000    0.2860   0.1180
# spotify:track:3Q9OB9hsyD5L0nc9nqEs6C          0.012200    0.0766   0.3230
# spotify:track:2x10hwxxBN13BRSX7uhmmA          0.783000    0.1530   0.1870
# spotify:track:4rcjT9jHzJS5esCbJwUlqe          0.008230    0.0702   0.4750
# spotify:track:1Aah00kVOuwwpnMDkoJMST          0.000246    0.1130   0.4340
#
#                                         tempo  duration_ms  time_signature
# track_uri
# spotify:track:0WLEwoxMXs9IFUgb2Jgevk  104.434      23027.0               5
# spotify:track:1BWb2tnk5LYKvPb4sifpjD  127.888     201562.0               4
# spotify:track:79UErtK3HJstQf7XykSmI3  161.050     208187.0               4
# spotify:track:5jDbwyetPAbzWU5YoTnHQ4  130.897     913278.0               4
# spotify:track:3WbYOiTaVcFfq9YETajLHz   92.729     446955.0               4
# spotify:track:3Kbh07ClPQUAFnf6e1mIum   98.037     218442.0               4
# spotify:track:2pCLewVg8ZoOKzLgurnrBQ   80.949     281560.0               4
# spotify:track:6culLN522QzyF4JTwnIBT8  124.270      69172.0               5
# spotify:track:6fWJFI8MXTBhMWr2Q0mayH  101.027     326008.0               4
# spotify:track:7pfm2SPFWlx3YhKPpFJjaM  171.948     231667.0               4
# spotify:track:4Ax24dp7sD4da6WcqjICqw  131.909     106480.0               4
# spotify:track:3Q9OB9hsyD5L0nc9nqEs6C  127.978     301874.0               4
# spotify:track:2x10hwxxBN13BRSX7uhmmA  125.005     245800.0               4
# spotify:track:4rcjT9jHzJS5esCbJwUlqe  120.055     265536.0               4
# spotify:track:1Aah00kVOuwwpnMDkoJMST   92.980     319787.0               4

# %% [markdown]
# #### Pre-requisite :
# Before running the next cell, ensure to have run `4_gather_node_degree_information.py` either directly from command line as Python script or run the `batch-job-4-gather-node-degree-info.sh` that runs the aforementioned Python program on a Slurm cluster.

# %%
node_degree_file = glob.glob('{}/*.parquet'.format(
    dataBaseDirectory + "/spotify_track_node_degree_buckets"))
print("Number of parquet files for node_degree_file were found to be : {}".format(len(node_degree_file)))

nodeDegreeCountsDf = pd.read_parquet(node_degree_file)
# Out:
# Number of parquet files for node_degree_file were found to be : 1

# %%
nodeDegreeCountsDf.head(10)
# Out:
#       buckets   count
# 0  5000-10000   44995
# 1   2000-5000  112286
# 2   1000-2000  144926
# 3      50-100  325434
# 4     100-200  572169
# 5        0-10    8388
# 6    500-1000  224884
# 7      >10000   40393
# 8       10-50  219655
# 9     200-500  569061

# %%
# Define order to see results in
bucketsOrder = ['0-10','10-50','50-100','100-200','200-500','500-1000','1000-2000','2000-5000','5000-10000','>10000']

# Define the chart using Altair
chart = alt.Chart(nodeDegreeCountsDf).mark_bar().encode( 
    x=alt.X('buckets:O'
            , sort=bucketsOrder, axis=alt.Axis(title='Degree of node', labelFontSize=12)),  # O for ordinal, which indicates categorical data
    y=alt.Y('count:Q'
            , axis=alt.Axis(title='Number of tracks', labelFontSize=12))   # Q for quantitative, which indicates numerical data
).properties(
    title=alt.TitleParams(text='Degree Distribution of Nodes(songs) in the Network', fontSize=20),  # Set the title font size to 12
    width=400
).configure_axis(
    labelFontSize=12  # Adjust the font size of axis labels
)

# Show the chart
chart
# Out:
# alt.Chart(...)

# %% [markdown]
# #### Pre-requisite :
# Before running the next cell, ensure to have run `6_pytorch_geometric_data_obj_generator.py` either directly from command line as Python script or run the `batch-job-6-pytorch-geometric-data-generator.sh` that runs the aforementioned Python program on a Slurm cluster.

# %%
# After running batch-6 script, you will have data representations available
# , pick out the folder name and use as dataVersion below
dataVersion = 'version_20230804_030210'
versionDirectoryName = '{}/{}'.format(dataBaseDirectory + "/saved_files/data_representations", dataVersion)

# Pick out the 1st from the list (assume there is only 1 in each version directory as per design)
search_path = os.path.join(versionDirectoryName, 'data_obj_*.pkl')

try:
    matching_file = glob.glob(search_path)[0]
    print(matching_file)
except:
    print("""
    Error: Check if folder you provided as argument exists inside 'saved_folder/data_representations'.
    Path to review the contents is : {}.
    """.format(dataBaseDirectory))

with open(matching_file, 'rb') as file:
    data = pickle.load(file)
print("The entire 'data' object has the below representation : \n{}".format(data))
# Out:
# /scratch/siads699s23_class_root/siads699s23_class/shared_data/team_16_algorhythms/data/spark_table_warehouse/saved_files/data_representations/version_20230804_030210/data_obj_2262191_nodes_2297244876_edges_20230804_030210.pkl
# The entire 'data' object has the below representation :
# Data(x=[2262191, 29], edge_index=[2, 2297244876], edge_weight=[2297244876], num_nodes=2262191)

# %%
xRanges = [0, 0.0001,0.001,0.01,0.1,1,10,100,1000] # Define range on x-axis
hist, edges = np.histogram(data.edge_weight.numpy(), bins=xRanges) # Generate histogram data based on ranges

# Generate in bucket ranges
bucket_counts = []
for i in range(len(xRanges) - 1):
    label = f"{xRanges[i]}-{xRanges[i+1]}"
    count = int(hist[i])
    bucket_counts.append((label, count))

# Setup as pandas dataframe to be able to use in altair
edgeWeightRangesDf = pd.DataFrame(bucket_counts, columns=['Range', 'Count'])

# Desired ordering 
bucketsOrder = [label for label,count in bucket_counts]
# Display as bar chart
chart = alt.Chart(edgeWeightRangesDf).mark_bar().encode(
    x=alt.X('Range:O', sort=bucketsOrder, axis=alt.Axis(title='Edge weight of edge', labelFontSize=12)),
    y=alt.Y('Count:Q', scale=alt.Scale(type='symlog')
            , axis=alt.Axis(title='Number of edges (in log scale)', labelFontSize=12)),
    #y=alt.Y('Count'),
).properties(
    title=alt.TitleParams(text='Log-Scaled Distribution of Edge weights in the Network', fontSize=20),
    width=400
).configure_axis(
    labelFontSize=12  # Adjust the font size of axis labels
)


chart
# Out:
# alt.Chart(...)
